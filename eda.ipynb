# %%
import pandas as pd

# %%
cases_train = pd.read_csv('./data/cases_2021_train_processed.csv')

# %%
hist = cases_train[["latitude", "longitude"]].plot.hist(bins=60)

# %%
fig = hist.get_figure()
fig.savefig('../plots/task-1.3/lat-long-hist.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [20], in <cell line: 2>()
#       1 fig = hist.get_figure()
# ----> 2 fig.savefig('../plots/task-1.3/lat-long-hist.png')
#
# File ~/opt/anaconda3/envs/CMPT459/lib/python3.10/site-packages/matplotlib/figure.py:3272, in Figure.savefig(self, fname, transparent, **kwargs)
#    3268     for ax in self.axes:
#    3269         stack.enter_context(
#    3270             ax.patch._cm_set(facecolor='none', edgecolor='none'))
# -> 3272 self.canvas.print_figure(fname, **kwargs)
#
# File ~/opt/anaconda3/envs/CMPT459/lib/python3.10/site-packages/matplotlib/backend_bases.py:2338, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2334 try:
#    2335     # _get_renderer may change the figure dpi (as vector formats
# ...
